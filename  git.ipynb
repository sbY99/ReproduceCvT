# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd /content/gdrive/MyDrive/FinalProject
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/FinalProject'
# /content

# %%
# !echo '# FinalProject' >> README.md
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/FinalProject/.git/

# %%
# !git config --global user.email 'didtmdqlsdl@gmail.com'
# !git config --global user.name 'sbY99'

# %%
# !git add README.md
# !git commit -m 'first commit'
# !git branch -M main
# Out:
# [master (root-commit) 347d534] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md

# %%
! git remote add origin https://sbY99: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@github.com/sbY99/ReproduceCvT.git

# %%
# !git push -u origin main
# Out:
# To https://github.com/sbY99/ReproduceCvT.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://sbY99: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@github.com/sbY99/ReproduceCvT.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git remote rm origin

# %%
from os.path import join


# path to your project on Google Drive
MY_GOOGLE_DRIVE_PATH = '/content/gdrive/MyDrive/FinalProject/ReproduceCvT' 
# replace with your Github username 
GIT_USERNAME = "sbY99" 
# definitely replace with your
GIT_TOKEN = "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"  
# Replace with your github repository in this case we want 
# to clone deep-learning-v2-pytorch repository
GIT_REPOSITORY = "ReproduceCvT" 

PROJECT_PATH = join('/root', MY_GOOGLE_DRIVE_PATH)

# It's good to print out the value if you are not sure 
print("PROJECT_PATH: ", PROJECT_PATH)   

# In case we haven't created the folder already; we will create a folder in the project path 
# !mkdir "{PROJECT_PATH}"    

#GIT_PATH = "https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git" this return 400 Bad Request for me
GIT_PATH = "https://" + GIT_TOKEN + "@github.com/" + GIT_USERNAME + "/" + GIT_REPOSITORY + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# PROJECT_PATH:  /content/gdrive/MyDrive/FinalProject/ReproduceCvT
# GIT_PATH:  https://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@github.com/sbY99/ReproduceCvT.git

# %%
cd /content/gdrive/MyDrive/FinalProject/ReproduceCvT
# Out:
# /content/gdrive/MyDrive/FinalProject/ReproduceCvT

# %%
# !git clone "{GIT_PATH}" . # clone the github repository
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %% [markdown]
# ##수정

# %%
cd /content/gdrive/MyDrive/FinalProject/ReproduceCvT
# Out:
# /content/gdrive/MyDrive/FinalProject/ReproduceCvT

# %%
ls

# %%
# !git config --global user.email didtmdqlsdl@gmail.com
# !git config --global user.name sbY99

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .
# !git commit -m 'init'
# !git push
# Out:
# ^C
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	AblationPosEmb/
#
# nothing added to commit but untracked files present
# Everything up-to-date
